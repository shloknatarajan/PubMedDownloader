# %%
# Run this cell: 
# The lines below will instruct jupyter to reload imported modules before 
# executing code cells. This enables you to quickly iterate and test revisions
# to your code without having to restart the kernel and reload all of your 
# modules each time you make a code change in a separate python file.

# %load_ext autoreload
# %autoreload 2

# %%
# load the pmcid mapping
import json
pmcid_mapping = json.load(open("data/pmcid_mapping.json"))

# load a list of pmids
pmids = list(pmcid_mapping.keys())

# %%
from src.markdown_from_pmid import save_batch_markdown_from_pmids

# %%
save_batch_markdown_from_pmids(pmids)
# Out:
#   0%|          | 0/4262 [00:00<?, ?it/s]2025-05-29 14:18:16.353 | INFO     | src.pmcid_from_pmid:batch_pmcid_from_pmid:47 - Processing PMIDs 1 to 1...
# 2025-05-29 14:18:16.600 | INFO     | src.pmcid_from_pmid:batch_pmcid_from_pmid:66 - PMID 12895196 → PMCID PMC1884285
# 2025-05-29 14:18:17.005 | INFO     | src.markdown_from_pmid:get_markdown_from_pmid:46 - PMCID found for PMID 12895196: PMC1884285
# 2025-05-29 14:18:17.005 | INFO     | src.html_from_pmcid:get_html_from_pmcid:29 - Fetching article from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1884285/?report=classic
# 2025-05-29 14:18:17.352 | INFO     | src.markdown_from_pmid:get_markdown_from_pmid:54 - HTML found for PMCID PMC1884285
#   0%|          | 1/4262 [00:01<1:13:16,  1.03s/it]2025-05-29 14:18:17.385 | INFO     | src.pmcid_from_pmid:batch_pmcid_from_pmid:47 - Processing PMIDs 1 to 1...
# 2025-05-29 14:18:17.615 | INFO     | src.pmcid_from_pmid:batch_pmcid_from_pmid:66 - PMID 17872605 → PMCID PMC1952551
# ...
