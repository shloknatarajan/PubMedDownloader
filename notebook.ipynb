# %%
# Run this cell: 
# The lines below will instruct jupyter to reload imported modules before 
# executing code cells. This enables you to quickly iterate and test revisions
# to your code without having to restart the kernel and reload all of your 
# modules each time you make a code change in a separate python file.

# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
records = pd.read_csv("data/record_map.csv")

# %%
records.head()
# Out:
#        PMID       PMCID                markdown_path  \
# 0  25051018  PMC4160394  data/articles/PMC4160394.md
# 1  17517247  PMC1978168  data/articles/PMC1978168.md
# 2  34423496  PMC8571740  data/articles/PMC8571740.md
# 3  23712427  PMC3674704  data/articles/PMC3674704.md
# 4  27121899  PMC6375065  data/articles/PMC6375065.md
#
#                                                  URL
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8...
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...

# %%
pmcids = records['PMCID'].tolist()

# %%
# Conert to html
from src.html_from_pmcid import get_html_from_pmcid

# %%
get_html_from_pmcid(pmcids[0:2])
# Out:
# 2025-05-30 15:24:31.489 | INFO     | src.html_from_pmcid:get_html_from_pmcid:69 - Starting processing of 2 PMCIDs
# 0it [00:00, ?it/s]2025-05-30 15:24:31.511 | INFO     | src.html_from_pmcid:fetch_single_pmcid:39 - Fetching article from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4160394/?report=classic
# 2025-05-30 15:24:31.861 | INFO     | src.html_from_pmcid:get_html_from_pmcid:81 - Processed 1/2 PMCIDs (Success: 1, Failed: 0)
# 1it [00:01,  1.36s/it]2025-05-30 15:24:32.869 | INFO     | src.html_from_pmcid:fetch_single_pmcid:39 - Fetching article from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1978168/?report=classic
# 2025-05-30 15:24:33.257 | INFO     | src.html_from_pmcid:get_html_from_pmcid:81 - Processed 2/2 PMCIDs (Success: 2, Failed: 0)
# 2it [00:01,  1.14it/s]
# 2025-05-30 15:24:33.264 | INFO     | src.html_from_pmcid:get_html_from_pmcid:88 - Processing completed. Total: 2, Success: 2, Failed: 0
# ...

# %%
pmids = records['PMID'].tolist()

# %%
from src.pmcid_from_pmid import get_pmcid_from_pmid
converted_pmids = get_pmcid_from_pmid(pmids)
print(converted_pmids)
# Out:
# 2025-05-30 15:26:19.412 | INFO     | src.pmcid_from_pmid:get_pmcid_from_pmid:22 - Starting conversion of 621 PMIDs to PMCIDs
# ...
# Converting PMIDs to PMCIDs: 100%|██████████| 7/7 [00:04<00:00,  1.46batch/s]
# 2025-05-30 15:26:24.209 | INFO     | src.pmcid_from_pmid:get_pmcid_from_pmid:44 - Processed 621 PMIDs
# ...

# %%
from src.markdown_from_pmid import get_markdown_from_pmid

# %%
get_markdown_from_pmid(pmids[0:5])
# Out:
# 2025-05-30 15:44:48.715 | INFO     | src.markdown_from_pmid:get_markdown_from_pmid:20 - Starting processing of 5 PMIDs
# 2025-05-30 15:44:48.717 | INFO     | src.pmcid_from_pmid:get_pmcid_from_pmid:22 - Starting conversion of 5 PMIDs to PMCIDs
# ...
# Converting PMIDs to PMCIDs: 100%|██████████| 1/1 [00:00<00:00,  1.55batch/s]
# 2025-05-30 15:44:49.365 | INFO     | src.pmcid_from_pmid:get_pmcid_from_pmid:44 - Processed 5 PMIDs
# 0it [00:00, ?it/s]2025-05-30 15:44:49.380 | WARNING  | src.markdown_from_pmid:get_markdown_from_pmid:30 - No PMCID found for PMID 17517247
# 2025-05-30 15:44:49.380 | WARNING  | src.markdown_from_pmid:get_markdown_from_pmid:30 - No PMCID found for PMID 34423496
# 2025-05-30 15:44:49.381 | WARNING  | src.markdown_from_pmid:get_markdown_from_pmid:30 - No PMCID found for PMID 23712427
# 2025-05-30 15:44:49.381 | WARNING  | src.markdown_from_pmid:get_markdown_from_pmid:30 - No PMCID found for PMID 27121899
# 4it [00:00, 2673.66it/s]
# ...
